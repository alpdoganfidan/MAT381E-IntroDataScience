# %% [markdown]
# # Some ground rules for the assignments:
#
# For all assignments (this one and any future assignment including the final project):
#
# * Do not download and save the data locally unless your data is very big (~TBs). I **do not** want to see you opening a local file for the data I gave you as an URL. Anything local is suspect: local files can't be trusted (they might be manipulated, changed, modified, tempered.) Refer to my lecture notes on how to pull data from an URL using `urlopen`.
#
# * All computations must be done locally within python. Nothing external: no manual input, no excel, no SQL, no java, etc.
#
# * All code has to be explained. Explain your reasoning and your choices. If you installed a third party library (including `numpy`, `scipy`, `pandas` etc), explain which part you import and what that function does etc.
#
# * Explain your code using a markdown cell. **Do not** use code comments starting with `#` to do your explanations.
#
# * Do not use `if __name__ == "__main__"`. EVER! If you are using that within jupyter, I am going to assume you found the solution on the internet and you cut/pasted without understanding what that peice of code did.

# %% [markdown]
# # Question 1
#
# Istanbul municipality has a open data service, and it provides detailed information about their services. For this question, use the data given at [this link](https://data.ibb.gov.tr/dataset/istanbul-sehir-hatlari-iskeleleri).
#
# 1. Understand what the data is for. Explain what it is, what it records, what pieces it has in broad strokes.
#
# 2. Data (among other things) contains geographical locations of Sea Stations ('Iskele') of Istanbul Deniz Isletmeleri boats operating in Istanbul.  Extract the locations of these stations as a pandas dataframe with 2 columns: latitudes and longitudes. The index of the dataframe has to be the station names.
#
# The data is in XML format. Do not use any external libraries other than numpy and pandas. Use `xmltodict` to convert it into a dictionary then extract the necessary parts.

# %% [markdown]
# <hr>

# %% [markdown]
# 1. This dataset contains the locations of the Wharfs located in Istanbul and managed by Şehir Hatları. There are 5 groups of wharfs and each of them contains stations. The stations is showed in the map by their own coordinates; latitudes and longtitudes. We want to get the list of coordinates of the stations.

# %% [markdown]
# 2. First, Library Urlopen was imported in order to reach the page which includes the data. Moreover, Library parse from xmltodict was imported since the data is stored in KML format which is based on the XML. Finally, Library Pandas was imported because we are dealing with data itself.

# %%
from urllib.request import urlopen
from xmltodict import parse
import pandas as pd

# %% [markdown]
# Raw data from url is being retrieved. The type of the raw is actually KML.

# %%
with urlopen("https://data.ibb.gov.tr/dataset/b47b5391-bcca-4bb3-a575-8ece68901d5d/resource/bcbeff5d-14d7-4ec0-a211-4c4d3e96cfba/download/istanbul-ehir-hatlar-iskeleleri.kml") as url:
    raw = url.read().decode('utf8')

# %% [markdown]
# By using imported function parse, the raw data is parsed from XML to Dictionary type.

# %%
data = parse(raw)

# %% [markdown]
# We reach to the essential part where it contains all infos of the whole stations in the KML Format.

# %%
wharfdata = data['kml']['Document']['Folder']['Folder']
wharfdata
# Out:
# [OrderedDict([('name', 'MERKEZ İSKELELER'),
#               ('open', '1'),
#               ('Placemark',
#                [OrderedDict([('name', 'MALTEPE'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2020-06-16')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.13060758098593'),
#                                            ('latitude', '40.91681013544846'),
#                                            ('altitude', '0'),
#                                            ('heading', '19.00402160686864'),
#                                            ('tilt', '30.00006999966086'),
#                                            ('range', '366.647238074807'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina8'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.12942483812604,40.91734348460334,0')]))]),
#                 OrderedDict([('name', 'AHIRKAPI'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2020-08-25')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.98289668101853'),
#                                            ('latitude', '41.00314456999032'),
#                                            ('altitude', '88.44065195618191'),
#                                            ('heading', '-18.52369222823391'),
#                                            ('tilt', '29.18194445617984'),
#                                            ('roll', '-4.106590502287532'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina8'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.98235555555555,41.00356388888889,0')]))]),
#                 OrderedDict([('name', 'BEŞİKTAŞ-1'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2017-06-14')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.00778819900819'),
#                                            ('latitude', '41.04116198628195'),
#                                            ('altitude', '0'),
#                                            ('heading', '-0.02429832115258925'),
#                                            ('tilt', '30.00091903188671'),
#                                            ('range', '204.6585195724259'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina0201'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.00734241946241,41.04102185617403,0')]))]),
#                 OrderedDict([('name', 'BEŞİKTAŞ-2'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-07-10')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.0055048939288'),
#                                            ('latitude', '41.04065414312002'),
#                                            ('altitude', '0'),
#                                            ('heading', '-26.12934386295936'),
#                                            ('tilt', '39.97306045424953'),
#                                            ('range', '261.6157538698276'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina0201'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.00558191801622,41.04002449784738,0')]))]),
#                 OrderedDict([('name', 'BOSTANCI'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2017-06-14')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.09425745312653'),
#                                            ('latitude', '40.95173395654253'),
#                                            ('altitude', '0'),
#                                            ('heading', '18.98020782019594'),
#                                            ('tilt', '29.99926571625897'),
#                                            ('range', '187.6619478086304'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina9'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.09401111111111,40.95158333333334,0')]))]),
#                 OrderedDict([('name', 'EMİNÖNÜ-1'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-07-10')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.97621869809887'),
#                                            ('latitude', '41.01495987953694'),
#                                            ('altitude', '533.3167707566636'),
#                                            ('heading', '-18.52807651848335'),
#                                            ('tilt', '29.18194578775841'),
#                                            ('roll', '-4.10533432704749'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina5'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.97621738960244,41.01698333333334,0')]))]),
#                 OrderedDict([('name', 'EMİNÖNÜ-2'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-07-10')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.97621869809887'),
#                                            ('latitude', '41.01495987953694'),
#                                            ('altitude', '533.3167707566636'),
#                                            ('heading', '-18.52807651848335'),
#                                            ('tilt', '29.18194578775841'),
#                                            ('roll', '-4.10533432704749'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina0201'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.97515218238153,41.0174085577444,0')]))]),
#                 OrderedDict([('name', 'EMİNÖNÜ-3'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-07-10')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.97495985342729'),
#                                            ('latitude', '41.01488637107048'),
#                                            ('altitude', '529.0271582010822'),
#                                            ('heading', '-18.52890269750091'),
#                                            ('tilt', '29.18151109941117'),
#                                            ('roll', '-4.105334326681596'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina10000'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.97406446282712,41.01786168465788,0')]))]),
#                 OrderedDict([('name', 'EMİNÖNÜ-4'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-07-10')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.97495985342729'),
#                                            ('latitude', '41.01488637107048'),
#                                            ('altitude', '529.0271582010822'),
#                                            ('heading', '-18.52890269750091'),
#                                            ('tilt', '29.18151109941117'),
#                                            ('roll', '-4.105334326681596'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina10000'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.97300956442612,41.0181957876729,0')]))]),
#                 OrderedDict([('name', 'HAYDARPAŞA'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2017-06-14')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.01810215560077'),
#                                            ('latitude', '40.99577360085738'),
#                                            ('altitude', '84.04994875024883'),
#                                            ('heading', '-18.38246313299776'),
#                                            ('tilt', '29.99948465489214'),
#                                            ('roll', '-4.009138435892832'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina21'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.01794166666667,40.99616388888889,0')]))]),
#                 OrderedDict([('name', 'KABATAŞ'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2019-03-09')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.99325211289065'),
#                                            ('latitude', '41.03138737936629'),
#                                            ('altitude', '1484.475884650949'),
#                                            ('heading', '-18.28758875548145'),
#                                            ('tilt', '9.339125534082827'),
#                                            ('roll', '-4.938676858354609'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina023'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.99370019962921,41.03481014260802,0')]))]),
#                 OrderedDict([('name', 'KADIKÖY-1'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-07-10')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.02211572735011'),
#                                            ('latitude', '40.99098891945888'),
#                                            ('altitude', '245.4353990766223'),
#                                            ('heading', '-18.37975689566163'),
#                                            ('tilt', '29.99999880163233'),
#                                            ('roll', '-4.009733854092751'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina22'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.02165863315933,40.99163473769475,0')]))]),
#                 OrderedDict([('name', 'KADIKÖY-2'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-07-10')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.02378422054707'),
#                                            ('latitude', '40.99126123485841'),
#                                            ('altitude', '618.4322106577139'),
#                                            ('heading', '-18.37880973262662'),
#                                            ('tilt', '29.99947464911061'),
#                                            ('roll', '-4.008556226926413'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina22'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.0230065597861,40.99283649461786,0')]))]),
#                 OrderedDict([('name', 'KARAKÖY'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeSpan',
#                                             OrderedDict([('begin',
#                                                           '2019-11-19T12:29:44.56006734Z'),
#                                                          ('end',
#                                                           '2019-11-19T12:29:44.560068803Z')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.97590906576235'),
#                                            ('latitude', '41.02205353005713'),
#                                            ('altitude', '456.4770994194125'),
#                                            ('heading', '-107.059343357383'),
#                                            ('tilt', '2.002675408063231'),
#                                            ('roll', '-91.36648163355329'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina20'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.97677897496515,41.02146605587114,0')]))]),
#                 OrderedDict([('name', 'KARAKÖY-2'),
#                              ('LookAt',
#                               OrderedDict([('longitude', '28.97517820592657'),
#                                            ('latitude', '41.02151363263756'),
#                                            ('altitude', '0'),
#                                            ('heading', '-153.334078192614'),
#                                            ('tilt', '30.00014157914941'),
#                                            ('range', '148.4706608656738'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina5'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.97514444444444,41.02157777777778,0')]))]),
#                 OrderedDict([('name', 'MODA'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2018-03-30')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.02468630924241'),
#                                            ('latitude', '40.97875652067077'),
#                                            ('altitude', '0'),
#                                            ('heading', '-3.705833992180612'),
#                                            ('tilt', '0'),
#                                            ('range', '625.3704758617437'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina500'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.02509917705279,40.97891439713442,0')]))]),
#                 OrderedDict([('name', 'ÜSKÜDAR'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2017-05-25')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.01517043640954'),
#                                            ('latitude', '41.02727798596923'),
#                                            ('altitude', '0'),
#                                            ('heading',
#                                             '-1.272221872585407e-14'),
#                                            ('tilt', '0'),
#                                            ('range', '346.0737490834642'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina20'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.01518463237754,41.0276024791138,0')]))])])]),
#  OrderedDict([('name', 'HALİÇ İSKELELERİ'),
#               ('Placemark',
#                [OrderedDict([('name', 'AYVANSARAY'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeSpan',
#                                             OrderedDict([('begin',
#                                                           '2017-10-17T00:00:35Z'),
#                                                          ('end',
#                                                           '2017-10-17')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.94481397672518'),
#                                            ('latitude', '41.04102545236506'),
#                                            ('altitude', '0'),
#                                            ('heading', '-56.47383781268692'),
#                                            ('tilt', '22.36046187013265'),
#                                            ('range', '116.0269843954669'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina023'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.94481666666667,41.04081111111111,0')]))]),
#                 OrderedDict([('name', 'BALAT'),
#                              ('LookAt',
#                               OrderedDict([('longitude', '28.9489827381236'),
#                                            ('latitude', '41.03490189638919'),
#                                            ('altitude', '0'),
#                                            ('heading', '-3.811205863638948'),
#                                            ('tilt', '0'),
#                                            ('range', '308.1189900303826'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina001'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.94917461627094,41.03490962679604,0')]))]),
#                 OrderedDict([('name', 'EMİNÖNÜ HALİÇ'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2017-05-25')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.97000636016617'),
#                                            ('latitude', '41.0211343157203'),
#                                            ('altitude', '0'),
#                                            ('heading', '-61.33175070727565'),
#                                            ('tilt', '0'),
#                                            ('range', '931.2853161721497'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina23'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.96897287762061,41.01944393929063,0')]))]),
#                 OrderedDict([('name', 'EYÜP SULTAN'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-03-18')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.93772446962244'),
#                                            ('latitude', '41.04757324587808'),
#                                            ('altitude', '0'),
#                                            ('heading', '-51.42693005364266'),
#                                            ('tilt', '30.00043438322602'),
#                                            ('range', '214.0406265573542'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina02'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.93781633169716,41.04728519275693,0')]))]),
#                 OrderedDict([('name', 'FENER'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeSpan',
#                                             OrderedDict([('begin',
#                                                           '2017-10-17T00:00:35Z'),
#                                                          ('end',
#                                                           '2017-10-17')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '28.95264940277138'),
#                                            ('latitude', '41.03107257160582'),
#                                            ('altitude', '0'),
#                                            ('heading', '0.01318466946204355'),
#                                            ('tilt', '35.08646951531122'),
#                                            ('range', '131.5125307424953'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina023'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.95262222222222,41.03095833333333,0')]))]),
#                 OrderedDict([('name', 'HASKÖY'),
#                              ('LookAt',
#                               OrderedDict([('longitude', '28.94926476460193'),
#                                            ('latitude', '41.04051288073612'),
#                                            ('altitude', '0'),
#                                            ('heading', '-3.811020602702142'),
#                                            ('tilt', '0'),
#                                            ('range', '187.950877877781'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina001'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '28.94910658441062,41.04069379545742,0')]))]),
#                 OrderedDict([('name', 'KASIMPAŞA'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2017-05-25')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
# ...
#                                            ('heading', '-24.50957067612524'),
#                                            ('tilt', '10.17508241714755'),
#                                            ('range', '117.9433296729538'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina023'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.02552777777778,41.04738055555556,0')]))]),
#                 OrderedDict([('name', 'POYRAZ'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-03-18')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.13087554026528'),
#                                            ('latitude', '41.20647961479241'),
#                                            ('altitude', '0'),
#                                            ('heading', '-17.74511772498959'),
#                                            ('tilt', '38.19454359138956'),
#                                            ('range', '239.0390467901196'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina6'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.13079746304965,41.20649735625906,0')]))]),
#                 OrderedDict([('name', 'PAŞABAHÇE'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-03-18')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.09328437602442'),
#                                            ('latitude', '41.11792570430826'),
#                                            ('altitude', '0'),
#                                            ('heading', '-17.78287112871759'),
#                                            ('tilt', '35.07475476962839'),
#                                            ('range', '389.4470806835868'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina023'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.09320263662477,41.11665497956218,0')]))]),
#                 OrderedDict([('name', 'RUMELİ KAVAĞI'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2014-03-18')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.0748362250914'),
#                                            ('latitude', '41.18247621378024'),
#                                            ('altitude', '0'),
#                                            ('heading', '-17.7395981979083'),
#                                            ('tilt', '60.00360243376988'),
#                                            ('range', '246.6428974096143'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina023'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.07500713540095,41.18168898317745,0')]))]),
#                 OrderedDict([('name', 'SARIYER'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2018-03-30')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.05750082659019'),
#                                            ('latitude', '41.16629742338651'),
#                                            ('altitude', '0'),
#                                            ('heading', '-3.684301668832843'),
#                                            ('tilt', '0'),
#                                            ('range', '776.0586494132003'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina70'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.05722664476868,41.16636354701346,0')]))]),
#                 OrderedDict([('name', 'YENİKÖY'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2017-06-14')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.07097570910133'),
#                                            ('latitude', '41.12167635650226'),
#                                            ('altitude', '0'),
#                                            ('heading', '-52.93658160515506'),
#                                            ('tilt', '11.03533567307069'),
#                                            ('range', '62.72656757829816'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina5'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.07103055555556,41.12165,0')]))])])]),
#  OrderedDict([('name', 'ARABALI İSKELELER'),
#               ('Placemark',
#                [OrderedDict([('name', 'ÇUBUKLU ARABALI'),
#                              ('Camera',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2019-04-06')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.08385836099203'),
#                                            ('latitude', '41.10772556533772'),
#                                            ('altitude', '220.0222181924932'),
#                                            ('heading', '-5.915092432779977'),
#                                            ('tilt', '21.41350651043993'),
#                                            ('roll', '-1.185802911421219'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina101'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.08312107755722,41.10858783049734,0')]))]),
#                 OrderedDict([('name', 'İSTİNYE ARABALI'),
#                              ('LookAt',
#                               OrderedDict([('gx:TimeStamp',
#                                             OrderedDict([('when',
#                                                           '2020-06-16')])),
#                                            ('gx:ViewerOptions',
#                                             OrderedDict([('gx:option',
#                                                           [OrderedDict([('@name',
#                                                                          'historicalimagery')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'sunlight')]),
#                                                            OrderedDict([('@enabled',
#                                                                          '0'),
#                                                                         ('@name',
#                                                                          'streetview')])])])),
#                                            ('longitude', '29.05709828076876'),
#                                            ('latitude', '41.11325361060186'),
#                                            ('altitude', '0'),
#                                            ('heading', '-3.24344670409207'),
#                                            ('tilt', '19.22915593437616'),
#                                            ('range', '121.8637488905867'),
#                                            ('gx:altitudeMode',
#                                             'relativeToSeaFloor')])),
#                              ('styleUrl', '#msn_marina101'),
#                              ('Point',
#                               OrderedDict([('gx:drawOrder', '1'),
#                                            ('coordinates',
#                                             '29.05678959615312,41.11337648913081,0')]))])])])]

# %% [markdown]
# We figure it out that there are 5 groups of wharfs located in İstanbul.

# %%
wharfgroups = [wharfgroup['name'] for wharfgroup in wharfdata]
wharfgroups
# Out:
# ['MERKEZ İSKELELER',
#  'HALİÇ İSKELELERİ',
#  'ADA İSKELELERİ',
#  'BOĞAZ İSKELELERİ',
#  'ARABALI İSKELELER']

# %% [markdown]
# Here is shown that how we can pull a 'longitude' info from a instance station.

# %%
wharfdata[0]['Placemark'][0]['LookAt']['longitude']
# Out:
# '29.13060758098593'

# %% [markdown]
# By going through to per wharfgroup, we pull the latitude and longitude values of stations and append them to an array called res. At the end, res is converted to a DataFrame by using a pandas function DataFrame().
#
# Note : The Coordinate info lies on keys 'LookAt' or 'Camera'. If it throws an exception when it is tried for key 'LookAt', then it will be tried for key 'Camera'.

# %%
res = []
i = 0
for wharfgroup in wharfdata :
    groupname = wharfgroup['name']
    for station in wharfgroup['Placemark'] :
        try:
            name = station["name"]
            lat = float(station['LookAt']['latitude'])
            long = float(station['LookAt']['longitude'])
            res.append({"name": name, "groupname": groupname, "lat": lat, "long": long})
        except Exception as e:
            try:
                name = station["name"]
                lat = float(station['Camera']['latitude'])
                long = float(station['Camera']['longitude'])
                res.append({"name": name, "groupname": groupname, "lat": lat, "long": long})
            except :
                i = i+1
        
stations = pd.DataFrame(res)
stations
# Out:
#                name          groupname        lat       long
# 0           MALTEPE   MERKEZ İSKELELER  40.916810  29.130608
# 1          AHIRKAPI   MERKEZ İSKELELER  41.003145  28.982897
# 2        BEŞİKTAŞ-1   MERKEZ İSKELELER  41.041162  29.007788
# 3        BEŞİKTAŞ-2   MERKEZ İSKELELER  41.040654  29.005505
# 4          BOSTANCI   MERKEZ İSKELELER  40.951734  29.094257
# 5         EMİNÖNÜ-1   MERKEZ İSKELELER  41.014960  28.976219
# 6         EMİNÖNÜ-2   MERKEZ İSKELELER  41.014960  28.976219
# 7         EMİNÖNÜ-3   MERKEZ İSKELELER  41.014886  28.974960
# 8         EMİNÖNÜ-4   MERKEZ İSKELELER  41.014886  28.974960
# 9        HAYDARPAŞA   MERKEZ İSKELELER  40.995774  29.018102
# 10          KABATAŞ   MERKEZ İSKELELER  41.031387  28.993252
# 11        KADIKÖY-1   MERKEZ İSKELELER  40.990989  29.022116
# 12        KADIKÖY-2   MERKEZ İSKELELER  40.991261  29.023784
# 13          KARAKÖY   MERKEZ İSKELELER  41.022054  28.975909
# 14        KARAKÖY-2   MERKEZ İSKELELER  41.021514  28.975178
# 15             MODA   MERKEZ İSKELELER  40.978757  29.024686
# 16          ÜSKÜDAR   MERKEZ İSKELELER  41.027278  29.015170
# 17       AYVANSARAY   HALİÇ İSKELELERİ  41.041025  28.944814
# 18            BALAT   HALİÇ İSKELELERİ  41.034902  28.948983
# 19    EMİNÖNÜ HALİÇ   HALİÇ İSKELELERİ  41.021134  28.970006
# 20      EYÜP SULTAN   HALİÇ İSKELELERİ  41.047573  28.937724
# 21            FENER   HALİÇ İSKELELERİ  41.031073  28.952649
# 22           HASKÖY   HALİÇ İSKELELERİ  41.040513  28.949265
# 23        KASIMPAŞA   HALİÇ İSKELELERİ  41.031314  28.966666
# 24          SÜTLÜCE   HALİÇ İSKELELERİ  41.047216  28.940692
# 25        BURGAZADA     ADA İSKELELERİ  40.880837  29.070870
# 26         BÜYÜKADA     ADA İSKELELERİ  40.874751  29.128130
# 27       HEYBELİADA     ADA İSKELELERİ  40.876851  29.101845
# 28        KINALIADA     ADA İSKELELERİ  40.910753  29.055678
# 29      SEDEF ADASI     ADA İSKELELERİ  40.852818  29.142221
# 30   ANADOLU HİSARI   BOĞAZ İSKELELERİ  41.083273  29.066509
# 31   ANADOLU KAVAĞI   BOĞAZ İSKELELERİ  41.173400  29.088158
# 32       ARNAVUTKÖY   BOĞAZ İSKELELERİ  41.067471  29.043794
# 33            BEBEK   BOĞAZ İSKELELERİ  41.076488  29.044472
# 34           BEYKOZ   BOĞAZ İSKELELERİ  41.134570  29.090317
# 35       BEYLERBEYİ   BOĞAZ İSKELELERİ  41.045130  29.044508
# 36        BÜYÜKDERE   BOĞAZ İSKELELERİ  41.161007  29.046066
# 37        ÇENGELKÖY   BOĞAZ İSKELELERİ  41.051054  29.051409
# 38          ÇUBUKLU   BOĞAZ İSKELELERİ  41.108066  29.080368
# 39          EMİRGAN   BOĞAZ İSKELELERİ  41.102344  29.056018
# 40  ÇUBUKLU ARABALI   BOĞAZ İSKELELERİ  41.108440  29.083370
# 41          İSTİNYE   BOĞAZ İSKELELERİ  41.113553  29.061495
# 42         KANDİLLİ   BOĞAZ İSKELELERİ  41.075194  29.058719
# 43          KANLICA   BOĞAZ İSKELELERİ  41.100573  29.065145
# 44        KUZGUNCUK   BOĞAZ İSKELELERİ  41.037549  29.029592
# 45          KÜÇÜKSU   BOĞAZ İSKELELERİ  41.079980  29.065561
# 46          ORTAKÖY   BOĞAZ İSKELELERİ  41.047496  29.025929
# 47           POYRAZ   BOĞAZ İSKELELERİ  41.206480  29.130876
# 48        PAŞABAHÇE   BOĞAZ İSKELELERİ  41.117926  29.093284
# 49    RUMELİ KAVAĞI   BOĞAZ İSKELELERİ  41.182476  29.074836
# 50          SARIYER   BOĞAZ İSKELELERİ  41.166297  29.057501
# 51          YENİKÖY   BOĞAZ İSKELELERİ  41.121676  29.070976
# 52  ÇUBUKLU ARABALI  ARABALI İSKELELER  41.107726  29.083858
# 53  İSTİNYE ARABALI  ARABALI İSKELELER  41.113254  29.057098

# %% [markdown]
# In the following, the index of the dataframe is converted to the station names.

# %%
stations.index = stations['name']
del stations['name']
stations
# Out:
#                          groupname        lat       long
# name
# MALTEPE           MERKEZ İSKELELER  40.916810  29.130608
# AHIRKAPI          MERKEZ İSKELELER  41.003145  28.982897
# BEŞİKTAŞ-1        MERKEZ İSKELELER  41.041162  29.007788
# BEŞİKTAŞ-2        MERKEZ İSKELELER  41.040654  29.005505
# BOSTANCI          MERKEZ İSKELELER  40.951734  29.094257
# EMİNÖNÜ-1         MERKEZ İSKELELER  41.014960  28.976219
# EMİNÖNÜ-2         MERKEZ İSKELELER  41.014960  28.976219
# EMİNÖNÜ-3         MERKEZ İSKELELER  41.014886  28.974960
# EMİNÖNÜ-4         MERKEZ İSKELELER  41.014886  28.974960
# HAYDARPAŞA        MERKEZ İSKELELER  40.995774  29.018102
# KABATAŞ           MERKEZ İSKELELER  41.031387  28.993252
# KADIKÖY-1         MERKEZ İSKELELER  40.990989  29.022116
# KADIKÖY-2         MERKEZ İSKELELER  40.991261  29.023784
# KARAKÖY           MERKEZ İSKELELER  41.022054  28.975909
# KARAKÖY-2         MERKEZ İSKELELER  41.021514  28.975178
# MODA              MERKEZ İSKELELER  40.978757  29.024686
# ÜSKÜDAR           MERKEZ İSKELELER  41.027278  29.015170
# AYVANSARAY        HALİÇ İSKELELERİ  41.041025  28.944814
# BALAT             HALİÇ İSKELELERİ  41.034902  28.948983
# EMİNÖNÜ HALİÇ     HALİÇ İSKELELERİ  41.021134  28.970006
# EYÜP SULTAN       HALİÇ İSKELELERİ  41.047573  28.937724
# FENER             HALİÇ İSKELELERİ  41.031073  28.952649
# HASKÖY            HALİÇ İSKELELERİ  41.040513  28.949265
# KASIMPAŞA         HALİÇ İSKELELERİ  41.031314  28.966666
# SÜTLÜCE           HALİÇ İSKELELERİ  41.047216  28.940692
# BURGAZADA           ADA İSKELELERİ  40.880837  29.070870
# BÜYÜKADA            ADA İSKELELERİ  40.874751  29.128130
# HEYBELİADA          ADA İSKELELERİ  40.876851  29.101845
# KINALIADA           ADA İSKELELERİ  40.910753  29.055678
# SEDEF ADASI         ADA İSKELELERİ  40.852818  29.142221
# ANADOLU HİSARI    BOĞAZ İSKELELERİ  41.083273  29.066509
# ANADOLU KAVAĞI    BOĞAZ İSKELELERİ  41.173400  29.088158
# ARNAVUTKÖY        BOĞAZ İSKELELERİ  41.067471  29.043794
# BEBEK             BOĞAZ İSKELELERİ  41.076488  29.044472
# BEYKOZ            BOĞAZ İSKELELERİ  41.134570  29.090317
# BEYLERBEYİ        BOĞAZ İSKELELERİ  41.045130  29.044508
# BÜYÜKDERE         BOĞAZ İSKELELERİ  41.161007  29.046066
# ÇENGELKÖY         BOĞAZ İSKELELERİ  41.051054  29.051409
# ÇUBUKLU           BOĞAZ İSKELELERİ  41.108066  29.080368
# EMİRGAN           BOĞAZ İSKELELERİ  41.102344  29.056018
# ÇUBUKLU ARABALI   BOĞAZ İSKELELERİ  41.108440  29.083370
# İSTİNYE           BOĞAZ İSKELELERİ  41.113553  29.061495
# KANDİLLİ          BOĞAZ İSKELELERİ  41.075194  29.058719
# KANLICA           BOĞAZ İSKELELERİ  41.100573  29.065145
# KUZGUNCUK         BOĞAZ İSKELELERİ  41.037549  29.029592
# KÜÇÜKSU           BOĞAZ İSKELELERİ  41.079980  29.065561
# ORTAKÖY           BOĞAZ İSKELELERİ  41.047496  29.025929
# POYRAZ            BOĞAZ İSKELELERİ  41.206480  29.130876
# PAŞABAHÇE         BOĞAZ İSKELELERİ  41.117926  29.093284
# RUMELİ KAVAĞI     BOĞAZ İSKELELERİ  41.182476  29.074836
# SARIYER           BOĞAZ İSKELELERİ  41.166297  29.057501
# YENİKÖY           BOĞAZ İSKELELERİ  41.121676  29.070976
# ÇUBUKLU ARABALI  ARABALI İSKELELER  41.107726  29.083858
# İSTİNYE ARABALI  ARABALI İSKELELER  41.113254  29.057098

# %% [markdown]
# # Question 2
#
# For this question we are going to use Istanbul Municipality data at [this link](https://data.ibb.gov.tr/dataset/sehir-hatlari-sefer-sayilari). Data contains Istanbul Deniz Isletmeleri route information.
#
# 1. Understand what the data is for, what it records, what it contains. Explain it in broad strokes.
# 2. Extract the data about the number of trips between stations.
# 2. Calculate the total number of trips in 2020,
# 3. Calculate the total number of trips in 2021,
# 4. Which is the busiest station in 2020 and 2021?
#
# For these questions you must extract the specific data you need from the raw data. Let me be very clear: I am not interested in the numerical answer, I'd like to see your data extraction and calculation explicitly. I need to see your code with which you extract the data, see the data frame where you record the extracted data, and the code where you group and calculate the required results.

# %% [markdown]
# <hr>

# %% [markdown]
# 1. It records the number of trips between stations in 2020 and also in 2021. It contains year, route and total number of trips.

# %% [markdown]
# 2. I imported numpy because of the Matrix operations such as sum() and argmax(). The others, pandas and urlopen, is imported with the same purpose in Question 1.

# %%
from urllib.request import urlopen
import pandas as pd
import numpy as np

# %% [markdown]
# In the following two steps, we get documents by URL. Since the documents are in CSV format, we extract the data with the function read_csv() and also parameter sep is used in the function to seperate the data combined with ';'.

# %%
url20="https://data.ibb.gov.tr/dataset/4be0d5f6-62de-4a24-a6a5-038009cde39f/resource/f1f95d5d-fa2f-479d-9d50-85ca1d604c1e/download/2020-yl-ehir-hatlar-sefer-saylar.csv"

with urlopen(url20) as url:
    data20 = pd.read_csv(url, encoding= 'unicode_escape', sep=";")
data20
# Out:
#      YIL                                           GÜZERGAH  \
# 0   2020                                 BEÞÝKTAÞ - KADIKÖY
# 1   2020                       KADIKÖY - KARAKÖY - BEÞÝKTAÞ
# 2   2020                                  EMÝNÖNÜ - ÜSKÜDAR
# 3   2020                        ÜSKÜDAR - KARAKÖY - EMÝNÖNÜ
# 4   2020                                  KADIKÖY - EMÝNÖNÜ
# 5   2020                                  KADIKÖY - KARAKÖY
# 6   2020              KABATAÞ - KADIKÖY - ADALAR - BOSTANCI
# 7   2020                                  ÝSTANBUL - ADALAR
# 8   2020                        KADIKÖY - KARAKÖY - EMÝNÖNÜ
# 9   2020  BOÐAZ GÝDÝÞ GELÝÞ (EMÝNÖNÜ - BEÞÝKTAÞ  -KUZGUN...
# 10  2020  BOÐAZ GÝDÝÞ GELÝÞ (EMÝNÖNÜ - BEÞÝKTAÞ - ORTAKÖ...
# 11  2020                     ÇENGELKÖY - BEÞÝKTAÞ - EMÝNÖNÜ
# 12  2020  ÜSKÜDAR - KARAKÖY - KASIMPAÞA - FENER - BALAT ...
# 13  2020                 KADIKÖY - EMÝRGAN (LALE SEFERLERÝ)
# 14  2020                   BOSTANCI - BÜYÜKADA - HEYBELÝADA
# 15  2020                              HEYBELÝADA - BÜYÜKADA
# 16  2020                                  BOSTANCI - ADALAR
# 17  2020                                BÜYÜKADA - BOSTANCI
# 18  2020                        BÜYÜKADA - KINALIADA (RÝNG)
# 19  2020        BEYKOZ - MUHTELÝF ÝSK. - BEÞÝKTAÞ - EMÝNÖNÜ
# 20  2020                   BEYKOZ - MUHTELÝF ÝSK. - EMÝNÖNÜ
# 21  2020                 A.HÝSARI - MUHTELÝF ÝSK. - EMÝNÖNÜ
# 22  2020        ÇENGELKÖY - BEYLERBEYÝ - BEÞÝKTAÞ - EMÝNÖNÜ
# 23  2020                      A.KAVAÐI - R.KAVAÐI - SARIYER
# 24  2020              ÇENGELKÖY - BEBEK - KANLICA - ÝSTÝNYE
# 25  2020                      KABATAÞ - KÜÇÜK SU - BEÞÝKTAÞ
# 26  2020  SARIYER - MUHTELÝF BOÐAZ - EMÝNÖNÜ (SARIYER - ...
# 27  2020                  BEYKOZ - MUHTELÝF BOÐAZ - ÜSKÜDAR
# 28  2020                                 KÜÇÜK SU - ÝSTÝNYE
# 29  2020                                  ADALAR - BEÞÝKTAÞ
# 30  2020                             BÜYÜKADA - SEDEF ADASI
# 31  2020             KADIKÖY - BEÞÝKTAÞ - ÝSTÝNYE - SARIYER
# 32  2020  A.KAVAÐI - BEYKOZ - PAÞABAHÇE - ÇUBUKLU - KANL...
# 33  2020  RUMELÝ KAVAÐI - SARIYER - ÝSTÝNYE - ARNAVUTKÖY...
# 34  2020                       BOSTANCI - KARAKÖY - KABATAÞ
#
#     TOPLAM SEFER ADETÝ
# 0               26.879
# 1               13.000
# 2               28.441
# 3                8.737
# 4               18.408
# 5               25.658
# 6                5.879
# 7                4.542
# 8               11.156
# 9              523.000
# 10             613.000
# 11               1.056
# 12              10.549
# 13               0.000
# 14               1.154
# 15             434.000
# 16               3.022
# 17               1.182
# 18             379.000
# 19             669.000
# 20             559.000
# 21             562.000
# 22               1.970
# 23              11.005
# 24               4.487
# 25               1.691
# 26             795.000
# 27             557.000
# 28               3.925
# 29               4.001
# 30               0.000
# 31             559.000
# 32               4.490
# 33               6.993
# 34               2.781

# %%
url21="https://data.ibb.gov.tr/dataset/4be0d5f6-62de-4a24-a6a5-038009cde39f/resource/d2c7e4c3-fd09-4952-8a8e-776e3accf91d/download/2021-yl-ehir-hatlar-sefer-saylar.csv"

with urlopen(url21) as url:
    data21 = pd.read_csv(url, encoding= 'unicode_escape', sep=";")
data21
# Out:
#        Yil                                           Guzergah  \
# 0   2021.0                                  BEÞÝKTAÞ-KADIKÖY
# 1   2021.0                                    EMÝNÖNÜ-ÜSKÜDAR
# 2   2021.0                                    EMÝNÖNÜ-KADIKÖY
# 3   2021.0  EMÝNÖNÜ-BEÞÝKTAÞ-KUZGUNCUK-BEYLERBEYÝ-ÇENGELKÖ...
# 4   2021.0  EMÝNÖNÜ-BEÞÝKTAÞ-ORTAKÖY-EMÝRGAN-PAÞABAHÇE-BEY...
# ..     ...                                                ...
# 70     NaN                                                NaN
# 71     NaN                                                NaN
# 72     NaN                                                NaN
# 73     NaN                                                NaN
# 74     NaN                                                NaN
#
#     Toplam Sefer Adeti
# 0               23.658
# 1               23.854
# 2               18.298
# 3              497.000
# 4              545.000
# ..                 ...
# 70                 NaN
# 71                 NaN
# 72                 NaN
# 73                 NaN
# 74                 NaN
#
# [75 rows x 3 columns]

# %% [markdown]
# 3. Sum is used on the column 'TOPLAM SEFER ADETÝ' of data20 to find the total number of trips in 2020.
# 4. Sum is used on the column 'Toplam Sefer Adeti' of data21 to find the total number of trips in 2021.

# %%
sumdata20 = data20['TOPLAM SEFER ADETÝ'].sum()
sumdata21 = data21['Toplam Sefer Adeti'].sum()
print('Total trips in 2020 is '+str(sumdata20)+ '\nTotal trips in 2021 is '+ str(sumdata21) )
# Out:
# Total trips in 2020 is 5851.006
# Total trips in 2021 is 8956.095

# %% [markdown]
# 5. With argmax, I find indice of max value and locate with iloc, which takes an indice as parameter. Furthermore, I get the busiest stations for each year 2020 and 2021.

# %%
maxdata20 = data20.iloc[data20['TOPLAM SEFER ADETÝ'].argmax()]
maxdata21 = data21.iloc[data21['Toplam Sefer Adeti'].argmax()]
print('The Busiest Station in 2020:\n'+str(maxdata20['GÜZERGAH'])+ '\n The Busiest Station in 2021:\n'+ str(maxdata21['Guzergah']) )
# Out:
# The Busiest Station in 2020:
# SARIYER - MUHTELÝF BOÐAZ - EMÝNÖNÜ (SARIYER - ÝSTÝNYE - EMÝRGAN - BEYLERBEYÝ - KUZGUNCUK - BEÞÝKTAÞ  - EMÝNÖNÜ)
#  The Busiest Station in 2021:
# BEBEK-ANADOLU HÝSARI-KANLICA-EMÝRGAN

# %% [markdown]
# # Question 3
#
# Using a different [dataset](https://data.ibb.gov.tr/dataset/istanbul-deniz-iskeleleri-yolcu-sayilari) again from Istanbul Municipality on Istanbul Deniz Isletmeleri:
#
# 1. Understand what the data is for, what it records, what it contains. Explain it in broad strokes.
# 2. Find out the busiest station in the years 2020 and 2021,
# 3. Repeat the same calculation monthly: find the busiest stations for each month.
# 4. Does your calculation of busiest stations agree with the calculation you made in Question #2? Explain.

# %% [markdown]
# <hr>

# %% [markdown]
# 1. It records the number of passengers passing through the wharfs located in Istanbul. It contains Year, Month, Authority Name, Station Name and Passenger Count.

# %%
with urlopen("https://data.ibb.gov.tr/dataset/20f33ff0-1ab3-4378-9998-486e28242f48/resource/6fbdd928-8c37-43a4-8e6a-ba0fa7f767fb/download/istanbul-deniz-iskeleleri-yolcu-saylar.csv") as url:
    data = pd.read_csv(url, encoding= 'unicode_escape', sep=";")
data
# Out:
#       Yil  Ay                                        Otorite Adi  \
# 0    2021   3  Beyden Deniz Ulaþým Hizmetleri Turizm ve Tic. ...
# 1    2021   3  Beyden Deniz Ulaþým Hizmetleri Turizm ve Tic. ...
# 2    2021   3  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...
# 3    2021   3  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...
# 4    2021   3  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...
# ..    ...  ..                                                ...
# 656  2021  11  TURYOL - S.S. TURÝZM VE YOLCU DENÝZ TAÞIYICILA...
# 657  2021  11  TURYOL - S.S. TURÝZM VE YOLCU DENÝZ TAÞIYICILA...
# 658  2021  11  TURYOL - S.S. TURÝZM VE YOLCU DENÝZ TAÞIYICILA...
# 659  2021  11  TURYOL - S.S. TURÝZM VE YOLCU DENÝZ TAÞIYICILA...
# 660  2021  11  TURYOL - S.S. TURÝZM VE YOLCU DENÝZ TAÞIYICILA...
#
#           Istasyon Adi  Yolcu Sayisi
# 0               BEYKOZ          5076
# 1              YENIKOY          5347
# 2             BESIKTAS        106334
# 3              KABATAS            24
# 4              USKUDAR         94200
# ..                 ...           ...
# 656            Eminönü         55387
# 657      Kadýköy Balon         40680
# 658  Kadýköy Çayýrbaþý         69443
# 659            Karaköy         55098
# 660            Üsküdar         26337
#
# [661 rows x 5 columns]

# %% [markdown]
# 2. When the data is filtered, there is no data about 2020.

# %%
data[(data["Yil"]==2020)]
# Out:
# Empty DataFrame
# Columns: [Yil, Ay, Otorite Adi, Istasyon Adi, Yolcu Sayisi]
# Index: []

# %% [markdown]
# 2. Again with argmax(), I find the index of max value of the column 'Yolcu Sayisi' when 'Yil' is 2021. Then I use iloc on the data.

# %%
data.iloc[data[(data["Yil"]==2021)]['Yolcu Sayisi'].argmax()]
# Out:
# Yil                                                          2021
# Ay                                                             10
# Otorite Adi     DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...
# Istasyon Adi                                             BESIKTAS
# Yolcu Sayisi                                               757374
# Name: 516, dtype: object

# %% [markdown]
# 3. Data is groupped by 'Ay' and 'Yil'. Then, a Pandas function called idxmax() is used to get positions of max indexes according to 'Yolcu Sayisi' for per Group. At the end, we find busiest stations for each month.

# %%
groupdata = data.loc[data.groupby(["Ay", "Yil"])["Yolcu Sayisi"].idxmax()]

groupdata.index = groupdata['Ay']
del groupdata['Ay']
groupdata
# Out:
#      Yil                                        Otorite Adi Istasyon Adi  \
# Ay
# 3   2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 4   2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 5   2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 6   2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 7   2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 8   2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 9   2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 10  2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
# 11  2021  DENTUR - AVRASYA DENÝZ TAÞ.TUR.HÝZ.ÝNÞ.SAN.TÝC...     BESIKTAS
#
#     Yolcu Sayisi
# Ay
# 3         106334
# 4         274984
# 5         205662
# 6         488048
# 7         590792
# 8         601089
# 9         633355
# 10        757374
# 11        223286

# %% [markdown]
# 4. I can not explain for 2020 because of no data.
# <br> On the other hand, for 2021, It is clear to see that station 'Beşiktaş' was the busiest one for per month in Question 3. Also, again for 2021, Beşiktaş is in the the busiest route in Question 2. So it is agree. (Normally it fits but unfortunately, we can not see it because of wrong decimal of values in Question 2)
